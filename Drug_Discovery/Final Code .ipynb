# %%
# %matplotlib inline
from load import *

# %%
nt650_targets = load_targets('data/nt650-targets.csv')

# %%
#nt650_targets[nt650_targets['object_name'].str.startswith('Dopamine D2 receptor')]
query = nt650_targets['object_name'].isin(['Dopamine D2 receptor', 'Serotonin 2 (5-HT2) receptor', 'glutamate', 'gaba','nicotinic'])
nt650_targets[query]
# Out:
#         compound_id  object_id object_external_id  \
# 129948           50       5577          CHEMBL339
# 129949           50       5518          CHEMBL217
# 129956           50       5598         CHEMBL3998
# 130157           90       5518          CHEMBL217
# 117593          162       5518          CHEMBL217
# 130609          162       5577          CHEMBL339
# 130611          162       5581      CHEMBL2093870
# 130614          162       5518          CHEMBL217
# 130622          162       5570      CHEMBL2095200
# 130640          162       5598         CHEMBL3998
# 130643          162       6056         CHEMBL3427
# 149825          762       8529          glutamate
# 118071         1838       5518          CHEMBL217
# 129843         2078       5518          CHEMBL217
# 131618         2079       5570      CHEMBL2095200
# 131659         2083       5570      CHEMBL2095200
# 129887         2084       5577          CHEMBL339
# 129915         2091       5577          CHEMBL339
# ...
